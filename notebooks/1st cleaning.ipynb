# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:\\Users\\ASUS\\Downloads\\dirty_cafe_sales.csv")
df.replace('UNKNOWN',np.nan,inplace=True)
df.replace('ERROR',np.nan,inplace=True)
df.isnull().sum()
df.fillna(method='ffill',inplace=True)
df.isnull().sum()
df
#df.duplicated().sum()
df.head(10)
df.tail(10)
df.dtypes
df['Total Spent']=pd.to_numeric(df['Total Spent'],errors='coerce')
df.dtypes
df.groupby('Item')['Total Spent'].sum()
#df.to_csv('d:/python/cleaned.csv',index=False)
#df.columns=df.columns.str.strip()
#df.to_csv('d:/python/final.csv',index=False)
#df=df.reset_index()
#df.to_csv('d:/python/my.csv',index=False)

#df.duplicated().sum()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21544\1741224081.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)
# Item
# Cake        11318.0
# Coffee       8301.0
# Cookie       4600.0
# Juice       11656.5
# Salad       17937.5
# Sandwich    14714.0
# Smoothie    14249.0
# Tea          6343.5
# Name: Total Spent, dtype: float64

# %%
pd.get_option('display.max_rows')
pd.reset_option('max_columns')

# %%
import pandas as pd

df=pd.read_csv('d:/python/my.csv')
df
# Out:
#       index Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0         0    TXN_1961373    Coffee         2             2.0          4.0
# 1         1    TXN_4977031      Cake         4             3.0         12.0
# 2         2    TXN_4271903    Cookie         4             1.0         12.0
# 3         3    TXN_7034554     Salad         2             5.0         10.0
# 4         4    TXN_3160411    Coffee         2             2.0          4.0
# ...     ...            ...       ...       ...             ...          ...
# 9995   9995    TXN_7672686    Coffee         2             2.0          4.0
# 9996   9996    TXN_9659401    Coffee         3             2.0          3.0
# 9997   9997    TXN_5255387    Coffee         4             2.0          8.0
# 9998   9998    TXN_7695629    Cookie         3             2.0          3.0
# 9999   9999    TXN_6170729  Sandwich         3             4.0         12.0
#
#       Payment Method  Location Transaction Date
# ...

# %%
df[df['Item']=='Coffee']
# Out:
#       index Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0         0    TXN_1961373  Coffee         2             2.0          4.0
# 4         4    TXN_3160411  Coffee         2             2.0          4.0
# 39       39    TXN_6688524  Coffee         4             2.0          8.0
# 75       75    TXN_6420335  Coffee         1             2.0          2.0
# 80       80    TXN_3748616  Coffee         2             2.0          4.0
# ...     ...            ...     ...       ...             ...          ...
# 9969   9969    TXN_9954652  Coffee         2             2.0          4.0
# 9990   9990    TXN_1538510  Coffee         5             2.0         10.0
# 9995   9995    TXN_7672686  Coffee         2             2.0          4.0
# 9996   9996    TXN_9659401  Coffee         3             2.0          3.0
# 9997   9997    TXN_5255387  Coffee         4             2.0          8.0
#
#       Payment Method  Location Transaction Date
# ...

# %%
I=['Cash']
df[df['Payment Method'].isin(I)]
# Out:
#       index Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 1         1    TXN_4977031      Cake         4             3.0         12.0
# 7         7    TXN_6699534  Sandwich         4             4.0         16.0
# 8         8    TXN_4717867  Sandwich         5             3.0         15.0
# 9         9    TXN_2064365  Sandwich         5             4.0         20.0
# 10       10    TXN_2548360     Salad         5             5.0         25.0
# ...     ...            ...       ...       ...             ...          ...
# 9992   9992    TXN_2739140  Smoothie         4             4.0         16.0
# 9993   9993    TXN_4766549  Smoothie         2             4.0         16.0
# 9994   9994    TXN_7851634  Smoothie         4             4.0         16.0
# 9995   9995    TXN_7672686    Coffee         2             2.0          4.0
# 9999   9999    TXN_6170729  Sandwich         3             4.0         12.0
#
#      Payment Method  Location Transaction Date
# ...

# %%
df[(df['Total Spent']>=10) & (df['Item']=='Sandwich')]
# Out:
#      Transaction ID      Item Quantity Price Per Unit  Total Spent  \
# 7       TXN_6699534  Sandwich        4            4.0         16.0
# 8       TXN_4717867  Sandwich        5            3.0         15.0
# 9       TXN_2064365  Sandwich        5            4.0         20.0
# 22      TXN_5132361  Sandwich        3            4.0         12.0
# 24      TXN_9400181  Sandwich        5            4.0         20.0
# ...             ...       ...      ...            ...          ...
# 9938    TXN_9357808  Sandwich        4            4.0         16.0
# 9962    TXN_4723089  Sandwich        4            4.0         16.0
# 9970    TXN_5762440  Sandwich        5            4.0         20.0
# 9991    TXN_3897619  Sandwich        3            4.0         12.0
# 9999    TXN_6170729  Sandwich        3            4.0         12.0
#
#       Payment Method  Location Transaction Date
# 7               Cash  Takeaway       2023-10-28
# 8               Cash  Takeaway       2023-07-28
# ...

# %%
df[df['Payment Method']=='Cash']
# Out:
#       index Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 1         1    TXN_4977031      Cake         4             3.0         12.0
# 7         7    TXN_6699534  Sandwich         4             4.0         16.0
# 8         8    TXN_4717867  Sandwich         5             3.0         15.0
# 9         9    TXN_2064365  Sandwich         5             4.0         20.0
# 10       10    TXN_2548360     Salad         5             5.0         25.0
# ...     ...            ...       ...       ...             ...          ...
# 9992   9992    TXN_2739140  Smoothie         4             4.0         16.0
# 9993   9993    TXN_4766549  Smoothie         2             4.0         16.0
# 9994   9994    TXN_7851634  Smoothie         4             4.0         16.0
# 9995   9995    TXN_7672686    Coffee         2             2.0          4.0
# 9999   9999    TXN_6170729  Sandwich         3             4.0         12.0
#
#      Payment Method  Location Transaction Date
# ...

# %%
df.groupby('Item')['Total Spent'].sum()
#df.groupby('Item')['Total Spent'].count()
# Out:
# Item
# Cake        11318.0
# Coffee       8301.0
# Cookie       4600.0
# Juice       11656.5
# Salad       17937.5
# Sandwich    14714.0
# Smoothie    14249.0
# Tea          6343.5
# Name: Total Spent, dtype: float64

# %%
df.groupby('Item')['Total Spent'].count()
# Out:
# Item
# Cake        1249
# Coffee      1298
# Cookie      1215
# Juice       1296
# Salad       1246
# Sandwich    1260
# Smoothie    1220
# Tea         1216
# Name: Total Spent, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('d:/python/my.csv')
df[(df['Item']=='Coffee') & (df['Payment Method']=='Cash') & (df['Location']=='In-store')]
# Out:
#       index Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 99       99    TXN_8779771  Coffee         4             2.0          8.0
# 136     136    TXN_6380550  Coffee         5             2.0         10.0
# 153     153    TXN_6541415  Coffee         1             3.0         12.0
# 154     154    TXN_4108138  Coffee         5             2.0         10.0
# 156     156    TXN_1928241  Coffee         3             2.0          6.0
# ...     ...            ...     ...       ...             ...          ...
# 9858   9858    TXN_6838411  Coffee         1             2.0          2.0
# 9882   9882    TXN_1728427  Coffee         5             2.0         10.0
# 9896   9896    TXN_9089045  Coffee         5             2.0         10.0
# 9969   9969    TXN_9954652  Coffee         2             2.0          4.0
# 9995   9995    TXN_7672686  Coffee         2             2.0          4.0
#
#      Payment Method  Location Transaction Date
# ...

# %%
import pandas as pd
df=pd.read_csv('d:/python/my.csv')
df.isnull().sum()
df.shape
# Out:
# (10000, 9)

# %%
import pandas as pd
df=pd.read_csv('d:/python/my.csv')
df['Price Per Unit']=pd.to_numeric(df['Price Per Unit'],errors='coerce')
df['Total Spent']=pd.to_numeric(df['Total Spent'],errors='coerce')
df['Quantity']=pd.to_numeric(df['Quantity'],errors='coerce')
df.dtypes
# Out:
# index                 int64
# Transaction ID       object
# Item                 object
# Quantity              int64
# Price Per Unit      float64
# Total Spent         float64
# Payment Method       object
# Location             object
# Transaction Date     object
# dtype: object

# %%
import pandas as pd
df=pd.read_csv('d:/python/my.csv')
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             10000 non-null  int64
#  1   Transaction ID    10000 non-null  object
#  2   Item              10000 non-null  object
#  3   Quantity          10000 non-null  int64
#  4   Price Per Unit    10000 non-null  float64
#  5   Total Spent       10000 non-null  float64
#  6   Payment Method    10000 non-null  object
#  7   Location          10000 non-null  object
#  8   Transaction Date  10000 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.3+ KB

# %%
import pandas as pd
df=pd.read_csv('d:/python/my.csv')
df['Payment Method'].isnull()
df['Transaction Date'].isnull()
df['Price Per Unit']=df['Price Per Unit'].astype('int64')
df.dtypes
df.head(12)
# Out:
#     index Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       0    TXN_1961373    Coffee         2               2          4.0
# 1       1    TXN_4977031      Cake         4               3         12.0
# 2       2    TXN_4271903    Cookie         4               1         12.0
# 3       3    TXN_7034554     Salad         2               5         10.0
# 4       4    TXN_3160411    Coffee         2               2          4.0
# 5       5    TXN_2602893  Smoothie         5               4         20.0
# 6       6    TXN_4433211  Smoothie         3               3          9.0
# 7       7    TXN_6699534  Sandwich         4               4         16.0
# 8       8    TXN_4717867  Sandwich         5               3         15.0
# 9       9    TXN_2064365  Sandwich         5               4         20.0
# 10     10    TXN_2548360     Salad         5               5         25.0
# 11     11    TXN_3051279  Sandwich         2               4          8.0
#
# ...

# %%
import pandas as pd
df=pd.read_csv('d:/python/my.csv')
df['Transaction Date']=pd.to_datetime(df['Transaction Date'],errors='coerce')
df['Price Per Unit']=df['Price Per Unit'].astype('int64')
df.dtypes
# Out:
# index                        int64
# Transaction ID              object
# Item                        object
# Quantity                     int64
# Price Per Unit               int64
# Total Spent                float64
# Payment Method              object
# Location                    object
# Transaction Date    datetime64[ns]
# dtype: object

# %%
import pandas as pd
df=pd.read_csv('d:/python/my.csv')
#df['Transaction ID'].duplicated().sum()
#df['Item'].unique() #for display uniques with names
df['Item'].nunique() #for count uniques
df.dtypes
# Out:
# index                 int64
# Transaction ID       object
# Item                 object
# Quantity              int64
# Price Per Unit      float64
# Total Spent         float64
# Payment Method       object
# Location             object
# Transaction Date     object
# dtype: object

# %%
df.dtypes
df
# Out:
#       index Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0         0    TXN_1961373    Coffee         2               2          4.0
# 1         1    TXN_4977031      Cake         4               3         12.0
# 2         2    TXN_4271903    Cookie         4               1         12.0
# 3         3    TXN_7034554     Salad         2               5         10.0
# 4         4    TXN_3160411    Coffee         2               2          4.0
# ...     ...            ...       ...       ...             ...          ...
# 9995   9995    TXN_7672686    Coffee         2               2          4.0
# 9996   9996    TXN_9659401    Coffee         3               2          3.0
# 9997   9997    TXN_5255387    Coffee         4               2          8.0
# 9998   9998    TXN_7695629    Cookie         3               2          3.0
# 9999   9999    TXN_6170729  Sandwich         3               4         12.0
#
#       Payment Method  Location Transaction Date
# ...

# %%
df.groupby('Item')['Total Spent'].agg(['sum','mean','median','max','min'])
# Out:
#               sum       mean  median   max  min
# Item
# Cake      11318.0   9.061649     9.0  25.0  1.0
# Coffee     8301.0   6.395223     6.0  25.0  1.0
# Cookie     4600.0   3.786008     3.0  25.0  1.0
# Juice     11656.5   8.994213     9.0  25.0  1.0
# Salad     17937.5  14.396067    15.0  25.0  1.0
# Sandwich  14714.0  11.677778    12.0  25.0  1.0
# Smoothie  14249.0  11.679508    12.0  25.0  1.0
# Tea        6343.5   5.216694     4.5  25.0  1.0

# %%
pt=df.pivot_table(index='Item',columns='Quantity',values='Total Spent',aggfunc='sum')
print(pt)
# Out:
# Quantity       1       2       3       4       5
# Item
# Cake       756.5  1620.0  2155.0  2924.5  3862.0
# Coffee     625.0  1189.0  1571.5  2010.0  2905.5
# Cookie     421.5   681.0   791.0  1218.0  1488.5
# Juice      851.0  1611.0  2445.0  2971.5  3778.0
# Salad     1380.0  2489.5  3268.5  4588.5  6211.0
# Sandwich  1096.5  1991.0  3009.5  3557.5  5059.5
# Smoothie  1032.5  1878.0  2775.5  3726.0  4837.0
# Tea        433.5  1030.5  1277.5  1469.0  2133.0

# %%
df.groupby('Item')['Quantity'].sum()
# Out:
# Item
# Cake        3805
# Coffee      3945
# Cookie      3619
# Juice       3891
# Salad       3761
# Sandwich    3845
# Smoothie    3727
# Tea         3699
# Name: Quantity, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('d:/python/my.csv')

df.dtypes
df['Transaction Date'].fillna(df['Transaction Date'].mode())
df
# Out:
#       index Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0         0    TXN_1961373    Coffee         2             2.0          4.0
# 1         1    TXN_4977031      Cake         4             3.0         12.0
# 2         2    TXN_4271903    Cookie         4             1.0         12.0
# 3         3    TXN_7034554     Salad         2             5.0         10.0
# 4         4    TXN_3160411    Coffee         2             2.0          4.0
# ...     ...            ...       ...       ...             ...          ...
# 9995   9995    TXN_7672686    Coffee         2             2.0          4.0
# 9996   9996    TXN_9659401    Coffee         3             2.0          3.0
# 9997   9997    TXN_5255387    Coffee         4             2.0          8.0
# 9998   9998    TXN_7695629    Cookie         3             2.0          3.0
# 9999   9999    TXN_6170729  Sandwich         3             4.0         12.0
#
#       Payment Method  Location Transaction Date
# ...

# %%
df['Price Per Unit'].value_counts()
# Out:
# Price Per Unit
# 3.0    2562
# 4.0    2465
# 2.0    1289
# 5.0    1275
# 1.0    1207
# 1.5    1202
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.figure(figsize=(12,10))
plt.hist(df['Price Per Unit'],bins=7)
plt.xlabel('price per units')
plt.ylabel('total value counts of products')
plt.show()

# %%
# Out:
# ([<matplotlib.patches.Wedge at 0x1ed74be3110>,
# ...
#  [Text(-0.006194606862322028, 1.0999825575189006, 'In-store'),
#   Text(0.006194571897715958, -1.0999825577158049, 'Takeaway')],
#  [Text(-0.0033788764703574694, 0.5999904859194002, '44720'),
#   Text(0.0033788573987541585, -0.5999904860268026, '44400')])

# %%
#df.groupby('Location')['Total Spent'].sum()
import matplotlib.pyplot as plt
spent_by_location=df.groupby('Location')['Total Spent'].sum()
index=spent_by_location.index
values=spent_by_location.values
def abs(pct):
    total=sum(values)
    absolute=int(round(pct*total/100))
    return f'{absolute}'
plt.pie(values,  labels=index,autopct=abs)
plt.show()

# %%
import pandas as pd
df=pd.read_csv('d:/python/my.csv')
df
df.groupby('Payment Method')['Total Spent'].sum()
# Out:
# Payment Method
# Cash              29310.0
# Credit Card       30205.0
# Digital Wallet    29604.5
# Name: Total Spent, dtype: float64

# %%
df.groupby('Payment Method')['Total Spent'].sum()
import matplotlib.pyplot as plt
totalpaymentbycategory=df.groupby('Payment Method')['Total Spent'].sum()
index=totalpaymentbycategory.index
values=totalpaymentbycategory.values
def abs(pct):
    total=sum(values)
    absolute=int(round(pct*total/100))
    return f'{absolute}'
plt.pie(values, labels=index ,autopct=abs)
plt.show()

# %%
df.groupby('Payment Method')['Total Spent'].sum()
# Out:
# Payment Method
# Cash              29310.0
# Credit Card       30205.0
# Digital Wallet    29604.5
# Name: Total Spent, dtype: float64

# %%
df.groupby('Item')['Total Spent'].sum()
# Out:
# Item
# Cake        11318.0
# Coffee       8301.0
# Cookie       4600.0
# Juice       11656.5
# Salad       17937.5
# Sandwich    14714.0
# Smoothie    14249.0
# Tea          6343.5
# Name: Total Spent, dtype: float64

# %%
import matplotlib.pyplot as plt
total=df.groupby('Item')['Total Spent'].sum()
plt.figure(figsize=(12,10))
plt.bar(total.index, total.values, label='total spends on items')
plt.xlabel('Total Spent')
plt.ylabel('Items')
plt.grid(True)
plt.title('Total Spends on Items')
plt.show()
